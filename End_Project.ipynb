# %%
import numpy as np
import pandas as pd
import math as m
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                          Name                    Team  Number Position  Age  \
# 0               Avery Bradley          Boston Celtics       0       PG   25
# 1                 Jae Crowder          Boston Celtics      99       SF   25
# 2                John Holland          Boston Celtics      30       SG   27
# 3                 R.J. Hunter          Boston Celtics      28       SG   22
# 4               Jonas Jerebko          Boston Celtics       8       PF   29
# 5                Amir Johnson          Boston Celtics      90       PF   29
# 6               Jordan Mickey          Boston Celtics      55       PF   21
# 7                Kelly Olynyk          Boston Celtics      41        C   25
# 8                Terry Rozier          Boston Celtics      12       PG   22
# 9                Marcus Smart          Boston Celtics      36       PG   22
# 10            Jared Sullinger          Boston Celtics       7        C   24
# ...

# %%
df.isna().sum()
# Out:
# Name         0
# Team         0
# Position     0
# Age          0
# Height       0
# Weight       0
# Salary      11
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
df['Height'].fillna(df['Height']:np.random.randint(150,180,457),inplace=True)
# Out:
#   Cell In[9], line 1
#     df['Height'].fillna(df['Height']:np.random.randint(150,180,457),inplace=True)
#                                     ^
# SyntaxError: invalid syntax

# %%
df.loc[df['Height'].isna(), 'Height'] = np.random.randint(150, 181, df['Height'].isna().sum())

# %%
df

# %%
df['Salary'].mean()

# %%
round(df['Salary'].mean(),2)

# %%
df['Salary'].fillna(df['Salary'].mean(),inplace= True)
# Out:
# C:\Users\ranje\AppData\Local\Temp\ipykernel_15140\1150117870.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].mean(),inplace= True)

# %%
df
# Out:
#                          Name                    Team Position  Age  \
# 0               Avery Bradley          Boston Celtics       PG   25
# 1                 Jae Crowder          Boston Celtics       SF   25
# 2                John Holland          Boston Celtics       SG   27
# 3                 R.J. Hunter          Boston Celtics       SG   22
# 4               Jonas Jerebko          Boston Celtics       PF   29
# 5                Amir Johnson          Boston Celtics       PF   29
# 6               Jordan Mickey          Boston Celtics       PF   21
# 7                Kelly Olynyk          Boston Celtics        C   25
# 8                Terry Rozier          Boston Celtics       PG   22
# 9                Marcus Smart          Boston Celtics       PG   22
# 10            Jared Sullinger          Boston Celtics        C   24
# 11              Isaiah Thomas          Boston Celtics       PG   27
# 12                Evan Turner          Boston Celtics       SG   27
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Position    0
# Age         0
# Height      0
# Weight      0
# Salary      0
# dtype: int64

# %%
max_salary = df['Salary'].max()
print (f'Maximum salary is:{max_salary}')
# Out:
# Maximum salary is:25000000.0

# %%
df.pop('College')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'College'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.pop('College')
#
# ...

# %%
df
# Out:
#                          Name                    Team Position  Age  \
# 0               Avery Bradley          Boston Celtics       PG   25
# 1                 Jae Crowder          Boston Celtics       SF   25
# 2                John Holland          Boston Celtics       SG   27
# 3                 R.J. Hunter          Boston Celtics       SG   22
# 4               Jonas Jerebko          Boston Celtics       PF   29
# 5                Amir Johnson          Boston Celtics       PF   29
# 6               Jordan Mickey          Boston Celtics       PF   21
# 7                Kelly Olynyk          Boston Celtics        C   25
# 8                Terry Rozier          Boston Celtics       PG   22
# 9                Marcus Smart          Boston Celtics       PG   22
# 10            Jared Sullinger          Boston Celtics        C   24
# 11              Isaiah Thomas          Boston Celtics       PG   27
# 12                Evan Turner          Boston Celtics       SG   27
# ...

# %%
df.pop('Number')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.pop('Number')
#
# ...

# %%
df
# Out:
#                          Name                    Team Position  Age  \
# 0               Avery Bradley          Boston Celtics       PG   25
# 1                 Jae Crowder          Boston Celtics       SF   25
# 2                John Holland          Boston Celtics       SG   27
# 3                 R.J. Hunter          Boston Celtics       SG   22
# 4               Jonas Jerebko          Boston Celtics       PF   29
# 5                Amir Johnson          Boston Celtics       PF   29
# 6               Jordan Mickey          Boston Celtics       PF   21
# 7                Kelly Olynyk          Boston Celtics        C   25
# 8                Terry Rozier          Boston Celtics       PG   22
# 9                Marcus Smart          Boston Celtics       PG   22
# 10            Jared Sullinger          Boston Celtics        C   24
# 11              Isaiah Thomas          Boston Celtics       PG   27
# 12                Evan Turner          Boston Celtics       SG   27
# ...

# %%
round(df['Salary'],2)
# Out:
# 0       7730337.00
# 1       6796117.00
# 2       4833969.55
# 3       1148640.00
# 4       5000000.00
# 5      12000000.00
# 6       1170960.00
# 7       2165160.00
# 8       1824360.00
# 9       3431040.00
# 10      2569260.00
# 11      6912869.00
# 12      3425510.00
# 13      1749840.00
# 14      2616975.00
# 15      3425510.00
# 16       845059.00
# 17      1500000.00
# 18      1335480.00
# 19      6300000.00
# 20      1599840.00
# 21       134215.00
# 22      1500000.00
# 23     19689000.00
# 24      1140240.00
# 25       947276.00
# 26       981348.00
# 27       947276.00
# 28       947276.00
# 29     11235955.00
# 30      8000000.00
# 31      1635476.00
# 32        30888.00
# 33     22875000.00
# 34      7402812.00
# 35       845059.00
# 36       845059.00
# 37      1572360.00
# 38     12650000.00
# 39      3750000.00
# 40      4131720.00
# 41      2814000.00
# 42      1636842.00
# 43       947276.00
# 44      4000000.00
# 45       167406.00
# 46      4833969.55
# ...

# %%
df
# Out:
#                          Name                    Team Position  Age  \
# 0               Avery Bradley          Boston Celtics       PG   25
# 1                 Jae Crowder          Boston Celtics       SF   25
# 2                John Holland          Boston Celtics       SG   27
# 3                 R.J. Hunter          Boston Celtics       SG   22
# 4               Jonas Jerebko          Boston Celtics       PF   29
# 5                Amir Johnson          Boston Celtics       PF   29
# 6               Jordan Mickey          Boston Celtics       PF   21
# 7                Kelly Olynyk          Boston Celtics        C   25
# 8                Terry Rozier          Boston Celtics       PG   22
# 9                Marcus Smart          Boston Celtics       PG   22
# 10            Jared Sullinger          Boston Celtics        C   24
# 11              Isaiah Thomas          Boston Celtics       PG   27
# 12                Evan Turner          Boston Celtics       SG   27
# ...

# %%
team_counts = df['Team'].value_counts()
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percentage = (team_counts/team_counts.sum())*100
print (f'Percentage of each team is:{percentage}')
# Out:
# Percentage of each team is:Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
team_counts = df['Team'].value_counts()
percentages = (team_counts / team_counts.sum()) * 100

plt.figure(figsize=(10, 8))
bars =sns.barplot(x=team_counts.values, y=team_counts.index, color='#01F9C6')
plt.title('Employee Distribution by Team')
plt.xlabel('Count')
plt.ylabel('Teams')
plt.xticks(rotation=90)

plt.show()

#Height employee distribution by a team is New Orleans Pelicans and Memphis Grizzlies .

# %%
custum_colors = ['#33afff','#ffa233','#ffe933','#2cb26f','#752cb2']

plt.figure(figsize=(10, 6))
position_counts = df['Position'].value_counts()
plt.pie(position_counts, labels=position_counts.index, autopct='%1.1f%%', colors =custum_colors )
plt.title('Position Distribution')
plt.show()
print (f'Total number of  Position Distribution is:{position_counts}')
# Out:
# Total number of  Position Distribution is:Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
bins=[20,25,30,35,40]
labels = ['20-25','26-30','31-40']
age_group_count = df['Age'].value_counts()
plt.figure(figsize=(8,5))
sns.histplot(df['Age'],bins = 5,kde = True)
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# In age group distribution the age between 20-25 have more employees comparing with other group.
# Out:
# Heighest age group distribution is between -5

# %%
salary_exp = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
max_salary = salary_exp.loc[salary_exp['Salary'].idxmax()]
print(max_salary)
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              31866445.0
# Name: 67, dtype: object

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = salary_exp,x='Salary',y='Team',hue='Position')
plt.title('Salary Expenditure')
plt.show()

# %%
correlation= df[['Age','Salary']].corr()
print(correlation)
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %%
plt.figure(figsize = (10,6))
sns.heatmap(data = correlation,annot=True,cmap ='mako',linewidth = 1.0)
plt.title('Age vs Salary')
plt.show()
